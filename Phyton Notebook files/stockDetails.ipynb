# %%
import mysql.connector
import requests
import mysql.connector
from bs4 import BeautifulSoup
from mysql.connector import Error

URL1 = 'https://finance.yahoo.com/quote/'
page = requests.get(URL1)

try:
    connection = mysql.connector.connect(host="localhost", user="root", password="MomDad@2020", database="HR_COMPANY_DATA")

    sql_Query = "Select COMPANY_ID,COMPANY_STOCK_SYM FROM HR_COMPANY_DATA.COMPANY_DETAILS WHERE PUBLIC_IND = 'public' "
    cursor = connection.cursor(dictionary=True)
    cursor.execute(sql_Query)
    records = cursor.fetchall()
    print("Total number of rows ", cursor.rowcount)

    # selecting column value into varible
    print("\nPrinting each Stock details\n\n")
    for row in records:
        symbol = row["COMPANY_STOCK_SYM"]
        
        details_page=requests.get("https://finance.yahoo.com/quote/"+symbol)
        details_page_html=BeautifulSoup(details_page.content,'html.parser')
        
        details_results = details_page_html.find('div',{"data-test":"quote-summary-stats"})
        for tr in details_results.find_all("tr"):
            inner_tds = tr.find_all("td")
            mycursor = connection.cursor()
            sql = "INSERT INTO COMPANY_STOCK_DETAILS (COMPANY_ID,COMPANY_STOCK_TITLE,COMPANY_STOCK_VALUE) VALUES (%s, %s,%s)"
            val = (row["COMPANY_ID"], ""+inner_tds[0].text, ""+inner_tds[1].text)
            mycursor.execute(sql, val)
            connection.commit()
            print (inner_tds[0].text+' | '+inner_tds[1].text)
        
        
except mysql.connector.Error as error:
    print("Failed to get record from database: {}".format(error))
else:
    print("sucess")
finally:
    if (connection.is_connected()):
        cursor.close()
        connection.close()
        #print("MySQL connection is closed")
# Out:
# Total number of rows  14
#
# Printing each Stock details
#
#
# Previous Close | 1,650.00
# Open | 1,650.00
# Bid | 1,630.00 x 0
# Ask | 1,635.00 x 0
# Day's Range | 1,620.00 - 1,650.00
# 52 Week Range | 970.00 - 1,890.00
# Volume | 9,461,200
# Avg. Volume | 14,677,283
# Market Cap | 27.987T
# Beta (5Y Monthly) | 0.70
# PE Ratio (TTM) | 27.12
# EPS (TTM) | 60.29
# Earnings Date | Oct 29, 2015 - Nov 03, 2015
# Forward Dividend & Yield | N/A (N/A)
# Ex-Dividend Date | May 24, 2019
# 1y Target Est | 1,588.20
# Previous Close | 121.95
# Open | 122.64
# Bid | 121.75 x 800
# Ask | 121.77 x 1300
# Day's Range | 121.55 - 123.20
# 52 Week Range | 80.03 - 130.24
# Volume | 523,120
# Avg. Volume | 5,166,957
# Market Cap | 60.777B
# Beta (5Y Monthly) | 0.79
# PE Ratio (TTM) | 22.51
# EPS (TTM) | 5.40
# Earnings Date | Aug 19, 2020
# Forward Dividend & Yield | 2.72 (2.23%)
# Ex-Dividend Date | Aug 18, 2020
# 1y Target Est | 129.59
# Previous Close | 23.93
# Open | 23.88
# Bid | 23.38 x 38500
# Ask | 23.39 x 800
# Day's Range | 23.34 - 23.97
# 52 Week Range | 17.95 - 35.72
# Volume | 22,434,191
# Avg. Volume | 73,457,174
# Market Cap | 203.053B
# Beta (5Y Monthly) | 1.59
# PE Ratio (TTM) | 11.26
# EPS (TTM) | 2.08
# Earnings Date | Oct 14, 2020
# Forward Dividend & Yield | 0.72 (3.01%)
# Ex-Dividend Date | Jun 04, 2020
# 1y Target Est | 28.53
# Previous Close | 63.36
# Open | 63.36
# Bid | 62.37 x 800
# Ask | 62.43 x 900
# Day's Range | 62.23 - 63.39
# 52 Week Range | 38.00 - 107.59
# Volume | 666,348
# Avg. Volume | 5,177,347
# Market Cap | 28.393B
# Beta (5Y Monthly) | 1.75
# PE Ratio (TTM) | 12.01
# EPS (TTM) | 5.19
# Earnings Date | Jul 21, 2020
# Forward Dividend & Yield | 1.60 (2.53%)
# Ex-Dividend Date | May 08, 2020
# 1y Target Est | 80.07
# Previous Close | 148.51
# Open | 149.40
# Bid | 148.05 x 3200
# Ask | 148.24 x 900
# Day's Range | 148.03 - 149.32
# 52 Week Range | 100.55 - 193.76
# Volume | 134,820
# Avg. Volume | 1,804,106
# Market Cap | 42.513B
# Beta (5Y Monthly) | N/A
# PE Ratio (TTM) | 12.50
# EPS (TTM) | N/A
# Earnings Date | Jul 29, 2020
# Forward Dividend & Yield | N/A (N/A)
# Ex-Dividend Date | N/A
# 1y Target Est | 169.24
# Previous Close | 16.20
# Open | 16.21
# Bid | 15.95 x 800
# Ask | 15.97 x 1300
# Day's Range | 15.94 - 16.35
# 52 Week Range | 9.87 - 31.99
# Volume | 539,853
# Avg. Volume | 3,845,017
# Market Cap | 7.03B
# Beta (5Y Monthly) | 1.55
# PE Ratio (TTM) | N/A
# EPS (TTM) | N/A
# Earnings Date | Jul 31, 2020 - Aug 04, 2020
# Forward Dividend & Yield | N/A (N/A)
# Ex-Dividend Date | Feb 06, 2020
# 1y Target Est | 17.33
# Previous Close | 53.91
# Open | 53.75
# Bid | 53.43 x 1200
# Ask | 53.44 x 900
# Day's Range | 53.38 - 53.93
# 52 Week Range | 32.58 - 102.70
# Volume | 293,783
# Avg. Volume | 2,930,003
# Market Cap | 105.189B
# Beta (5Y Monthly) | 1.13
# PE Ratio (TTM) | 32.36
# EPS (TTM) | 1.65
# Earnings Date | N/A
# Forward Dividend & Yield | 1.45 (2.69%)
# Ex-Dividend Date | Jun 09, 2020
# 1y Target Est | 58.22
# Previous Close | 29.56
# Open | 29.57
# Bid | 29.47 x 1000
# Ask | 29.48 x 900
# Day's Range | 29.42 - 29.71
# 52 Week Range | 18.98 - 32.00
# Volume | 343,505
# Avg. Volume | 4,308,793
# Market Cap | 41.419B
# Beta (5Y Monthly) | 0.51
# PE Ratio (TTM) | 35.46
# EPS (TTM) | 0.83
# Earnings Date | Aug 06, 2020 - Aug 10, 2020
# Forward Dividend & Yield | 0.60 (2.03%)
# Ex-Dividend Date | Jul 01, 2020
# 1y Target Est | 31.40
# Previous Close | 195.39
# Open | 195.60
# Bid | 194.22 x 800
# Ask | 194.70 x 800
# Day's Range | 194.28 - 196.12
# 52 Week Range | 156.15 - 288.59
# Volume | 13,372
# Avg. Volume | 194,647
# Market Cap | 4.898B
# Beta (5Y Monthly) | 1.24
# PE Ratio (TTM) | 17.91
# EPS (TTM) | 10.90
# Earnings Date | Aug 12, 2020
# Forward Dividend & Yield | N/A (N/A)
# Ex-Dividend Date | N/A
# 1y Target Est | 295.00
# Previous Close | 148.51
# Open | 149.40
# Bid | 148.05 x 3200
# Ask | 148.24 x 900
# Day's Range | 148.03 - 149.32
# 52 Week Range | 100.55 - 193.76
# Volume | 134,820
# Avg. Volume | 1,804,106
# Market Cap | 42.513B
# Beta (5Y Monthly) | N/A
# PE Ratio (TTM) | 12.50
# EPS (TTM) | N/A
# Earnings Date | Jul 29, 2020
# Forward Dividend & Yield | N/A (N/A)
# Ex-Dividend Date | N/A
# 1y Target Est | 169.24
# Previous Close | 365.88
# Open | 366.30
# Bid | 363.20 x 1000
# Ask | 363.46 x 900
# Day's Range | 362.85 - 367.47
# 52 Week Range | 266.11 - 442.53
# Volume | 263,616
# Avg. Volume | 1,528,063
# Market Cap | 101.991B
# Beta (5Y Monthly) | 0.96
# PE Ratio (TTM) | 16.50
# EPS (TTM) | 22.04
# Earnings Date | Jul 21, 2020
# Forward Dividend & Yield | 9.60 (2.62%)
# Ex-Dividend Date | Aug 31, 2020
# 1y Target Est | 433.72
# Previous Close | 303.65
# Open | 305.85
# Bid | 303.85 x 1000
# Ask | 304.00 x 900
# Day's Range | 303.57 - 307.04
# 52 Week Range | 263.31 - 385.01
# Volume | 190,210
# Avg. Volume | 965,717
# Market Cap | 50.722B
# Beta (5Y Monthly) | 0.79
# PE Ratio (TTM) | 22.90
# EPS (TTM) | 13.29
# Earnings Date | Jul 30, 2020
# Forward Dividend & Yield | 5.80 (1.91%)
# Ex-Dividend Date | May 29, 2020
# 1y Target Est | 393.18
# Previous Close | 62.37
# Open | 62.47
# Bid | 61.74 x 800
# Ask | 61.73 x 1100
# Day's Range | 61.71 - 62.61
# 52 Week Range | 43.44 - 99.71
# Volume | 1,593,461
# Avg. Volume | 11,575,276
# Market Cap | 93.713B
# Beta (5Y Monthly) | 0.85
# PE Ratio (TTM) | N/A
# EPS (TTM) | N/A
# Earnings Date | Jul 28, 2020
# Forward Dividend & Yield | 1.90 (3.05%)
# Ex-Dividend Date | Aug 13, 2020
# 1y Target Est | 76.25
# Previous Close | 71.51
# Open | 72.26
# Bid | 71.18 x 3200
# Ask | 71.25 x 1100
# Day's Range | 71.22 - 72.20
# 52 Week Range | 45.45 - 96.80
# Volume | 28,868
# Avg. Volume | 795,244
# Market Cap | 4.156B
# Beta (5Y Monthly) | 1.04
# PE Ratio (TTM) | 20.25
# EPS (TTM) | 3.53
# Earnings Date | Sep 03, 2020 - Sep 07, 2020
# Forward Dividend & Yield | 1.48 (2.07%)
# Ex-Dividend Date | Jul 16, 2020
# 1y Target Est | 103.50
# sucess
